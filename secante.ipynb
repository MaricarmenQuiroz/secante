# %%
import matplotlib.pyplot as plt 
import math

def MetodoSecante () :
   xi0 = ( 0 ) 
   print ( "Ingrese el valor de x: " ) 
   xi1 = int ( input ()) 
   print ( "Ingrese el criterio de paro" ) 
   c_paro = float ( input ()) 
   fg1 ( xi0 , xi1 , c_paro ) 
def g1 ( x ) : 
  return math.e** ( -x ) - x 
def fg1 ( X1 , X2 , c_paro = 0.0001 ) : 
  x_vec= [] 
  x_vec.append ( X1 ) 
  x_vec.append ( X2 ) 
  contador = ( 1 ) 
  error_vec= [] 
  error_vec.append ( 1 ) 
  error_vec.append ( 1 ) 
  
  while ( error_vec [ contador ] > c_paro ): 
   xi=x_vec [ contador ] 
   xi1=x_vec [ contador -1 ] 
   fxi=g1 ( xi ) 
   fxi1=g1 ( xi1 ) 
   x_temp= ( xi- (( fxi* ( xi1-xi )) / ( fxi1-fxi ))) 
   x_vec.append ( x_temp ) 
   e_temp= abs ( x_vec [ contador+ 1 ] -x_vec [ contador ]) 
   error_vec.append ( e_temp ) 
   contador+= 1 
  
  if ( x_vec [ contador ] >= 9999 ): 
   converge= False
   print ( "No converge" )
  else : 
   if ( x_vec [ contador ] <= 9999 ): 
     print ( "Si converge" ) 
  for xVec in x_vec :
   print ( "iteracion: " )
   print ( " " , xVec ) 
  for error in error_vec : 
   print ( "error: " ) 
   print ( " " , error )
 
   plt.plot ( x_vec , label = "Iteraciones" )
   plt.legend ()
   plt.show () 
   plt.plot ( error_vec , label = "error" , color = 'red' ) 
   plt.legend () 
   plt.show () 
   MetodoSecante ()
